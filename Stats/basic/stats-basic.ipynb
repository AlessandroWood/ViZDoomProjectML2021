# %% [markdown]
# # Statistiche del primo scenario (Basic)

# %%
import matplotlib.pyplot as plt
import json
import pandas as pd
import seaborn as sns
sns.set(rc={'figure.figsize':(20,10)})

# %% [markdown]
# # Vecchia Architettura Vs. Nuova Architettura

# %%
with open("stats_nuova_architettura.json") as json_file:
    stats_nuova_architettura = json.load(json_file)
with open("stats_vecchia_architettura.json") as json_file:
    stats_vecchia_architettura = json.load(json_file)

# %% [markdown]
# ## Train Scores

# %%
data1 = pd.DataFrame(stats_nuova_architettura["train_scores"])
data2 = pd.DataFrame(stats_vecchia_architettura["train_scores"])
plot = sns.lineplot(data=data1, x = range(1, stats_nuova_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_vecchia_architettura["epochs"] + 1), y="mean")
plt.legend(labels=["Nuova Architettura","Vecchia Architettura"])
plt.title('Modelli a confronto per epoca (train scores)')
plt.show()

# %% [markdown]
# ## Test Scores

# %%
data1 = pd.DataFrame(stats_nuova_architettura["test_scores"])
data2 = pd.DataFrame(stats_vecchia_architettura["test_scores"])
plot = sns.lineplot(data=data1, x = range(1, stats_nuova_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_vecchia_architettura["epochs"] + 1), y="mean")
plt.legend(labels=["Nuova Architettura","Vecchia Architettura"])
plt.title('Modelli a confronto per epoca (test scores)')
plt.show()

# %% [markdown]
# ## Loss Scores

# %%
data1 = pd.DataFrame(stats_nuova_architettura["loss"])
data2 = pd.DataFrame(stats_vecchia_architettura["loss"])
plot = sns.lineplot(data=data1, x = range(1, stats_nuova_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_vecchia_architettura["epochs"] + 1), y="mean")
plt.legend(labels=["Nuova Architettura","Vecchia Architettura"])
plt.title('Modelli a confronto per epoca (loss scores)')
plt.show()

# %% [markdown]
# # Double DQN Vs. Dueling DQN Vs. Double Dueling DQN

# %%
with open("stats_dqn_no_double_ma_dueling.json") as json_file:
    stats_dqn_no_double_ma_dueling = json.load(json_file)
with open("stats_dqn_no_dueling_ma_double.json") as json_file:
    stats_dqn_no_dueling_ma_double = json.load(json_file)

# %% [markdown]
# ## Train Scores

# %%
data1 = pd.DataFrame(stats_dqn_no_double_ma_dueling["train_scores"])
data2 = pd.DataFrame(stats_dqn_no_dueling_ma_double["train_scores"])
data3 = pd.DataFrame(stats_nuova_architettura["train_scores"])
plot = sns.lineplot(data=data1, x = range(1, stats_nuova_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_vecchia_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data3, x = range(1, stats_nuova_architettura["epochs"] + 1), y="mean")
plt.legend(labels=["Dueling DQN","Double DQN","Double Dueling DQN"])
plt.title('Tipologie di architetture a confronto per epoca (train scores)')
plt.show()

# %% [markdown]
# ## Test Score

# %%
data1 = pd.DataFrame(stats_dqn_no_double_ma_dueling["test_scores"])
data2 = pd.DataFrame(stats_dqn_no_dueling_ma_double["test_scores"])
data3 = pd.DataFrame(stats_nuova_architettura["test_scores"])
plot = sns.lineplot(data=data1, x = range(1, stats_nuova_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_vecchia_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data3, x = range(1, stats_nuova_architettura["epochs"] + 1), y="mean")
plt.legend(labels=["Dueling DQN","Double DQN","Double Dueling DQN"])
plt.title('Tipologie di architetture a confronto per epoca (test scores)')
plt.show()

# %% [markdown]
# # Update Target Net

# %%
with open("stats_update_1000step.json") as json_file:
    stats_update_1000step = json.load(json_file)
with open("stats_update_3000step.json") as json_file:
    stats_update_3000step = json.load(json_file)
with open("stats_update_10000step.json") as json_file:
    stats_update_10000step = json.load(json_file)

# %% [markdown]
# ## Train Scores

# %%
data1 = pd.DataFrame(stats_update_1000step["train_scores"])
data2 = pd.DataFrame(stats_update_3000step["train_scores"])
data3 = pd.DataFrame(stats_update_10000step["train_scores"])
plot = sns.lineplot(data=data1, x = range(1, stats_nuova_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_vecchia_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data3, x = range(1, stats_vecchia_architettura["epochs"] + 1), y="mean")
plt.legend(labels=["Update 1000 step","Update 3000 step","Update 10000 step"])
plt.title('Modelli a confronto con differenti update target net per epoca (train scores)')
plt.show()

# %% [markdown]
# ## Test Scores

# %%
data1 = pd.DataFrame(stats_update_1000step["test_scores"])
data2 = pd.DataFrame(stats_update_3000step["test_scores"])
data3 = pd.DataFrame(stats_update_10000step["test_scores"])
plot = sns.lineplot(data=data1, x = range(1, stats_nuova_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_vecchia_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data3, x = range(1, stats_vecchia_architettura["epochs"] + 1), y="mean")
plt.legend(labels=["Update 1000 step","Update 3000 step","Update 10000 step"])
plt.title('Modelli a confronto con differenti update target net per epoca (test scores)')
plt.show()

# %% [markdown]
# ## Loss Scores

# %%
data1 = pd.DataFrame(stats_update_1000step["loss"])
data2 = pd.DataFrame(stats_update_3000step["loss"])
data3 = pd.DataFrame(stats_update_10000step["loss"])
plot = sns.lineplot(data=data1, x = range(1, stats_nuova_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_vecchia_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data3, x = range(1, stats_vecchia_architettura["epochs"] + 1), y="mean")
plt.legend(labels=["Update 1000 step","Update 3000 step","Update 10000 step"])
plt.title('Modelli a confronto con differenti update target net per epoca (loss scores)')
plt.show()

# %% [markdown]
# # Frame Repeat

# %%
with open("stats_frame_repeat_4.json") as json_file:
    stats_frame_repeat_4 = json.load(json_file)
with open("stats_frame_repeat_8.json") as json_file:
    stats_frame_repeat_8 = json.load(json_file)
with open("stats_update_10000step.json") as json_file:
    stats_frame_repeat_12 = json.load(json_file)

# %% [markdown]
# ## Train Scores

# %%
data1 = pd.DataFrame(stats_frame_repeat_4["train_scores"])
data2 = pd.DataFrame(stats_frame_repeat_8["train_scores"])
data3 = pd.DataFrame(stats_frame_repeat_12["train_scores"])
plot = sns.lineplot(data=data1, x = range(1, stats_nuova_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_vecchia_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data3, x = range(1, stats_vecchia_architettura["epochs"] + 1), y="mean")
plt.legend(labels=["Frame Repeat 4","Frame Repeat 8","Frame Repeat 12"])
plt.title('Modelli a confronto con differenti frame repeat per epoca (train scores)')
plt.show()

# %% [markdown]
# ## Test Scores

# %%
data1 = pd.DataFrame(stats_frame_repeat_4["test_scores"])
data2 = pd.DataFrame(stats_frame_repeat_8["test_scores"])
data3 = pd.DataFrame(stats_frame_repeat_12["test_scores"])
plot = sns.lineplot(data=data1, x = range(1, stats_nuova_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_vecchia_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data3, x = range(1, stats_vecchia_architettura["epochs"] + 1), y="mean")
plt.legend(labels=["Frame Repeat 4","Frame Repeat 8","Frame Repeat 12"])
plt.title('Modelli a confronto con differenti frame repeat per epoca (test scores)')
plt.show()

# %% [markdown]
# ## Loss Scores

# %%
data1 = pd.DataFrame(stats_frame_repeat_4["loss"])
data2 = pd.DataFrame(stats_frame_repeat_8["loss"])
data3 = pd.DataFrame(stats_frame_repeat_12["loss"])
plot = sns.lineplot(data=data1, x = range(1, stats_nuova_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_vecchia_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data3, x = range(1, stats_vecchia_architettura["epochs"] + 1), y="mean")
plt.legend(labels=["Frame Repeat 4","Frame Repeat 8","Frame Repeat 12"])
plt.title('Modelli a confronto con differenti frame repeat per epoca (loss scores)')
plt.show()

# %% [markdown]
# # Batch Size

# %%
with open("stats_batch_size_32.json") as json_file:
    stats_batch_size_32 = json.load(json_file)
with open("stats_update_10000step.json") as json_file:
    stats_batch_size_64 = json.load(json_file)
with open("stats_batch_size_128.json") as json_file:
    stats_batch_size_128 = json.load(json_file)

# %% [markdown]
# ## Train Scores

# %%
data1 = pd.DataFrame(stats_batch_size_32["train_scores"])
data2 = pd.DataFrame(stats_batch_size_64["train_scores"])
data3 = pd.DataFrame(stats_batch_size_128["train_scores"])
plot = sns.lineplot(data=data1, x = range(1, stats_nuova_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_vecchia_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data3, x = range(1, stats_vecchia_architettura["epochs"] + 1), y="mean")
plt.legend(labels=["Batch size 32","Batch size 64","Batch size 128"])
plt.title('Modelli a confronto con differenti batch size per epoca (train scores)')
plt.show()

# %% [markdown]
# ## Test Scores

# %%
data1 = pd.DataFrame(stats_batch_size_32["test_scores"])
data2 = pd.DataFrame(stats_batch_size_64["test_scores"])
data3 = pd.DataFrame(stats_batch_size_128["test_scores"])
plot = sns.lineplot(data=data1, x = range(1, stats_nuova_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_vecchia_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data3, x = range(1, stats_vecchia_architettura["epochs"] + 1), y="mean")
plt.legend(labels=["Batch size 32","Batch size 64","Batch size 128"])
plt.title('Modelli a confronto con differenti batch size per epoca (test scores)')
plt.show()

# %% [markdown]
# ## Loss Scores

# %%
data1 = pd.DataFrame(stats_batch_size_32["loss"])
data2 = pd.DataFrame(stats_batch_size_64["loss"])
data3 = pd.DataFrame(stats_batch_size_128["loss"])
plot = sns.lineplot(data=data1, x = range(1, stats_nuova_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_vecchia_architettura["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data3, x = range(1, stats_vecchia_architettura["epochs"] + 1), y="mean")
plt.legend(labels=["Batch size 32","Batch size 64","Batch size 128"])
plt.title('Modelli a confronto con differenti batch size per epoca (loss scores)')
plt.show()

# %% [markdown]
# # Replay Memory Size

# %%
with open("stats_replay_size_5k.json") as json_file:
    stats_replay_size_5k = json.load(json_file)
with open("stats_update_10000step.json") as json_file:
    stats_replay_size_10k = json.load(json_file)
with open("stats_replay_size_50k.json") as json_file:
    stats_replay_size_50k = json.load(json_file)

# %% [markdown]
# ## Train Scores

# %%
data1 = pd.DataFrame(stats_replay_size_5k["train_scores"])
data2 = pd.DataFrame(stats_replay_size_10k["train_scores"])
data3 = pd.DataFrame(stats_replay_size_50k["train_scores"])
plot = sns.lineplot(data=data1, x = range(1, stats_replay_size_5k["epochs"] + 1 ), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_replay_size_10k["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data3, x = range(1, stats_replay_size_50k["epochs"] + 1), y="mean")
plt.legend(labels=["Replay Memory 5k","Replay Memory 10k","Replay Memory 50k"])
plt.title('Modelli a confronto con differenti replay memory per epoca (train scores)')
plt.show()

# %% [markdown]
# ## Test Scores

# %%
data1 = pd.DataFrame(stats_replay_size_5k["test_scores"])
data2 = pd.DataFrame(stats_replay_size_10k["test_scores"])
data3 = pd.DataFrame(stats_replay_size_50k["test_scores"])
plot = sns.lineplot(data=data1, x = range(1, stats_replay_size_5k["epochs"] + 1 ), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_replay_size_10k["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data3, x = range(1, stats_replay_size_50k["epochs"] + 1), y="mean")
plt.legend(labels=["Replay Memory 5k","Replay Memory 10k","Replay Memory 50k"])
plt.title('Modelli a confronto con differenti replay memory per epoca (test scores)')
plt.show()

# %% [markdown]
# ## Loss Scores

# %%
data1 = pd.DataFrame(stats_replay_size_5k["loss"])
data2 = pd.DataFrame(stats_replay_size_10k["loss"])
data3 = pd.DataFrame(stats_replay_size_50k["loss"])
plot = sns.lineplot(data=data1, x = range(1, stats_replay_size_5k["epochs"] + 1 ), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_replay_size_10k["epochs"] + 1), y="mean")
plot = sns.lineplot(data=data3, x = range(1, stats_replay_size_50k["epochs"] + 1), y="mean")
plt.legend(labels=["Replay Memory 5k","Replay Memory 10k","Replay Memory 50k"])
plt.title('Modelli a confronto con differenti replay memory per epoca (loss scores)')
plt.show()

# %% [markdown]
# # Epsilon Min

# %%
with open("stats_update_10000step.json") as json_file:
    stats_miglior_modello = json.load(json_file)
with open("stats-eps-min-005.json") as json_file:
    stats_eps = json.load(json_file)

# %% [markdown]
# ## Train Scores

# %%
data1 = pd.DataFrame(stats_miglior_modello["train_scores"])
data2 = pd.DataFrame(stats_eps["train_scores"])
plot = sns.lineplot(data=data1, x = range(1, stats_miglior_modello["epochs"]+1), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_eps["epochs"] + 1), y="mean")
plt.legend(labels=["Epsilon 0.1","Epsilon 0.05"])
plt.title('Modelli a confronto con differenti epsilon per epoca (train scores)')
plt.show()

# %% [markdown]
# ## Test Scores

# %%
data1 = pd.DataFrame(stats_miglior_modello["test_scores"])
data2 = pd.DataFrame(stats_eps["test_scores"])
plot = sns.lineplot(data=data1, x = range(1, stats_miglior_modello["epochs"]+1), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_eps["epochs"] + 1), y="mean")
plt.legend(labels=["Epsilon 0.1","Epsilon 0.05"])
plt.title('Modelli a confronto con differenti epsilon per epoca (loss scores)')
plt.show()

# %% [markdown]
# ## Loss Scores

# %%
data1 = pd.DataFrame(stats_miglior_modello["loss"])
data2 = pd.DataFrame(stats_eps["loss"])
plot = sns.lineplot(data=data1, x = range(1, stats_miglior_modello["epochs"]+1), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_eps["epochs"] + 1), y="mean")
plt.legend(labels=["Epsilon 0.1","Epsilon 0.05"])
plt.title('Modelli a confronto con differenti epsilon per epoca (loss scores)')
plt.show()

# %% [markdown]
# # Scala di grigi Vs. RGB

# %%
with open("stats_update_10000step.json") as json_file:
    stats_scala_grigi = json.load(json_file)
with open("stats-rgb.json") as json_file:
    stats_rgb = json.load(json_file)

# %% [markdown]
# ## Train Scores

# %%
data1 = pd.DataFrame(stats_scala_grigi["train_scores"])
data2 = pd.DataFrame(stats_rgb["train_scores"])
plot = sns.lineplot(data=data1, x = range(1, stats_scala_grigi["epochs"]+1), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_rgb["epochs"] + 1), y="mean")
plt.legend(labels=["Scala di Grigi","RGB"])
plt.title('Scala di grigi Vs. RGB per epoca (train scores)')
plt.show()

# %% [markdown]
# ## Test Scores

# %%
data1 = pd.DataFrame(stats_scala_grigi["test_scores"])
data2 = pd.DataFrame(stats_rgb["test_scores"])
plot = sns.lineplot(data=data1, x = range(1, stats_scala_grigi["epochs"]+1), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_rgb["epochs"] + 1), y="mean")
plt.legend(labels=["Scala di Grigi","RGB"])
plt.title('Scala di grigi Vs. RGB per epoca (test scores)')
plt.show()

# %% [markdown]
# ## Loss Scores

# %%
data1 = pd.DataFrame(stats_scala_grigi["loss"])
data2 = pd.DataFrame(stats_rgb["loss"])
plot = sns.lineplot(data=data1, x = range(1, stats_scala_grigi["epochs"]+1), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_rgb["epochs"] + 1), y="mean")
plt.legend(labels=["Scala di Grigi","RGB"])
plt.title('Scala di grigi Vs. RGB per epoca (loss scores)')
plt.show()

# %% [markdown]
# # Miglior modello Vs. primo modello

# %%
with open("stats_update_10000step.json") as json_file:
    stats_miglior_modello = json.load(json_file)
with open("stats_vecchia_architettura.json") as json_file:
    stats_primo_modello = json.load(json_file)

# %% [markdown]
# ## Train Scores

# %%
data1 = pd.DataFrame(stats_miglior_modello["train_scores"])
data2 = pd.DataFrame(stats_primo_modello["train_scores"])
plot = sns.lineplot(data=data1, x = range(1, stats_miglior_modello["epochs"]+1), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_primo_modello["epochs"] + 1), y="mean")
plt.legend(labels=["Miglior modello","Primo modello"])
plt.title('Miglior modello confrontato con il primo per epoca (train scores)')
plt.show()

# %% [markdown]
# ## Test Scores

# %%
data1 = pd.DataFrame(stats_miglior_modello["test_scores"])
data2 = pd.DataFrame(stats_primo_modello["test_scores"])
plot = sns.lineplot(data=data1, x = range(1, stats_miglior_modello["epochs"]+1), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_primo_modello["epochs"] + 1), y="mean")
plt.legend(labels=["Miglior modello","Primo modello"])
plt.title('Miglior modello confrontato con il primo per epoca (test scores)')
plt.show()

# %% [markdown]
# ## Loss Scores

# %%
data1 = pd.DataFrame(stats_miglior_modello["loss"])
data2 = pd.DataFrame(stats_primo_modello["loss"])
plot = sns.lineplot(data=data1, x = range(1, stats_miglior_modello["epochs"]+1), y="mean")
plot = sns.lineplot(data=data2, x = range(1, stats_primo_modello["epochs"] + 1), y="mean")
plt.legend(labels=["Miglior modello","Primo modello"])
plt.title('Miglior modello confrontato con il primo per epoca (loss scores)')
plt.show()
